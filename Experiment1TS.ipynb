# %% [markdown]
# <a href="https://colab.research.google.com/github/Hydenx2004/Time-series-lab/blob/main/Experiment1TS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('dailymintemp.csv',parse_dates=['Date'],index_col='Date')

# %%
df.head()
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8

# %%
df.tail()
# Out:
#             Temp
# Date
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0

# %%
feb85 = df.loc['1985-02']

# %%
feb85.head()
# Out:
#             Temp
# Date
# 1985-02-01  14.9
# 1985-02-02  10.2
# 1985-02-03  13.6
# 1985-02-04  19.0
# 1985-02-05  15.7

# %%
single_day = df.loc["1983-07-15"]
range_q   = df.loc["1982-12-20":"1982-12-31"]

# %%
df['Temp'].describe()
# Out:
# count    3650.000000
# mean       11.177753
# std         4.071837
# min         0.000000
# 25%         8.300000
# 50%        11.000000
# 75%        14.000000
# max        26.300000
# Name: Temp, dtype: float64
